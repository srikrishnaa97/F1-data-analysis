# %%
import fastf1
import pandas as pd

# %%
schedule = fastf1.get_event_schedule(2023)
schedule['EventDate'] = pd.to_datetime(schedule['EventDate']).dt.date
today = dt.datetime.now().date()
schedule['Days from Today'] = schedule.EventDate - today
schedule['Days from Today'] = schedule['Days from Today'].dt.days
past_events = schedule[schedule['Days from Today'] < 0]
len(past_events)
# Out:
# 8

# %%
type(dt.datetime.now().year)
# Out:
# int

# %%
def prepare_past_events(year):
    schedule = fastf1.get_event_schedule(year)
    schedule['EventDate'] = pd.to_datetime(schedule['EventDate']).dt.date
    today = dt.datetime.now().date()
    schedule['Days from Today'] = (schedule.EventDate - today).dt.days
    # print(schedule['Days from Today'].dtype)
    return schedule

events = prepare_past_events(2023)
past_events = events[events['Days from Today'] < 0]
past_events
# Out:
#    RoundNumber        Country   Location  \
# 0            0        Bahrain     Sakhir
# 1            1        Bahrain     Sakhir
# 2            2   Saudi Arabia     Jeddah
# 3            3      Australia  Melbourne
# 4            4     Azerbaijan       Baku
# 5            5  United States      Miami
# 6            6         Monaco     Monaco
# 7            7          Spain  Barcelona
#
#                              OfficialEventName  EventDate  \
# 0     FORMULA 1 ARAMCO PRE-SEASON TESTING 2023 2023-02-25
# 1   FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2023 2023-03-05
# 2  FORMULA 1 STC SAUDI ARABIAN GRAND PRIX 2023 2023-03-19
# 3   FORMULA 1 ROLEX AUSTRALIAN GRAND PRIX 2023 2023-04-02
# 4         FORMULA 1 AZERBAIJAN GRAND PRIX 2023 2023-04-30
# 5   FORMULA 1 CRYPTO.COM MIAMI GRAND PRIX 2023 2023-05-07
# 6          FORMULA 1 GRAND PRIX DE MONACO 2023 2023-05-28
# 7     FORMULA 1 AWS GRAN PREMIO DE ESPAÑA 2023 2023-06-04
#
#                   EventName      EventFormat    Session1  \
# ...

# %%
events.iloc[len(past_events) - 1]
# Out:
# RoundNumber                                                 7
# Country                                                 Spain
# Location                                            Barcelona
# OfficialEventName    FORMULA 1 AWS GRAN PREMIO DE ESPAÑA 2023
# EventDate                                          2023-06-04
# EventName                                  Spanish Grand Prix
# EventFormat                                      conventional
# Session1                                           Practice 1
# Session1Date                        2023-06-02 13:30:00+02:00
# Session1DateUtc                           2023-06-02 11:30:00
# Session2                                           Practice 2
# Session2Date                        2023-06-02 17:00:00+02:00
# Session2DateUtc                           2023-06-02 15:00:00
# Session3                                           Practice 3
# Session3Date                        2023-06-03 12:30:00+02:00
# ...

# %%
schedule = fastf1.get_event_schedule(2023)[['EventDate','EventName']]
schedule['EventDate'] = pd.to_datetime(schedule['EventDate']).dt.date
today = dt.datetime.now().date()
(schedule['EventDate'] - today).dt.days
# Out:
# 0    -107
# 1     -99
# 2     -85
# 3     -71
# 4     -43
# 5     -36
# 6     -15
# 7      -8
# 8       6
# 9      20
# 10     27
# 11     41
# 12     48
# 13     76
# 14     83
# 15     97
# 16    104
# 17    118
# 18    132
# 19    139
# 20    146
# 21    159
# 22    167
# Name: EventDate, dtype: int64

# %%
schedule = fastf1.get_event_schedule(2023)
schedule[schedule['EventName']=='Spanish Grand Prix'].T
# Out:
#                                                           7
# RoundNumber                                               7
# Country                                               Spain
# Location                                          Barcelona
# OfficialEventName  FORMULA 1 AWS GRAN PREMIO DE ESPAÑA 2023
# EventDate                               2023-06-04 00:00:00
# EventName                                Spanish Grand Prix
# EventFormat                                    conventional
# Session1                                         Practice 1
# Session1Date                      2023-06-02 13:30:00+02:00
# Session1DateUtc                         2023-06-02 11:30:00
# Session2                                         Practice 2
# Session2Date                      2023-06-02 17:00:00+02:00
# Session2DateUtc                         2023-06-02 15:00:00
# Session3                                         Practice 3
# Session3Date                      2023-06-03 12:30:00+02:00
# ...

# %%
import datetime as dt
dt.datetime.now().date()
# Out:
# datetime.date(2023, 6, 12)

# %%
dt.datetime.now().date().year
# Out:
# 2023

# %%
import fastf1
import pandas as pd
import datetime as dt

# %%
def get_event_schedule_data(year):
    schedule = fastf1.get_event_schedule(year)
    schedule['EventDate'] = pd.to_datetime(schedule['EventDate'])
    today = dt.datetime.now()
    schedule['Days from Today'] = (schedule['EventDate'] - today).dt.days
    return schedule 
# print(f'{current_year} | {latest_event}')

get_event_schedule_data(2023)
# Out:
#     RoundNumber        Country           Location  \
# 0             0        Bahrain             Sakhir
# 1             1        Bahrain             Sakhir
# 2             2   Saudi Arabia             Jeddah
# 3             3      Australia          Melbourne
# 4             4     Azerbaijan               Baku
# 5             5  United States              Miami
# 6             6         Monaco             Monaco
# 7             7          Spain          Barcelona
# 8             8         Canada           Montréal
# 9             9        Austria          Spielberg
# 10           10  Great Britain        Silverstone
# 11           11        Hungary           Budapest
# 12           12        Belgium  Spa-Francorchamps
# 13           13    Netherlands          Zandvoort
# 14           14          Italy              Monza
# 15           15      Singapore         Marina Bay
# 16           16          Japan             Suzuka
# 17           17          Qatar             Lusail
# ...

# %%
fastf1.get_event?
# Out:
# Signature:
# fastf1.get_event(
#     year: int,
#     gp: Union[int, str],
#     *,
#     backend: Optional[Literal['fastf1', 'f1timing', 'ergast']] = None,
#     force_ergast: bool = False,
#     strict_search: bool = False,
# ) -> 'Event'
# Docstring:
# Create an :class:`~fastf1.events.Event` object for a specific
# season and gp.
#
# To get a testing event, use :func:`get_testing_event`.
#
# Args:
#     year: Championship year
#
#     gp: Name as str or round number as int. If gp is
#         a string, a fuzzy match will be performed on all events and the
#         closest match will be selected.
#         Fuzzy matching uses country, location, name and officialName of
#         each event as reference.
#         Note that the round number cannot be used to get a testing event,
#         as all testing event are round 0!
#
#     backend: select a specific backend as data source, options:
#
#         - ``'fastf1'``: FastF1's own backend, full support for 2018 to now
#
# ...

# %%
fastf1.get_event(2023,'spanish')
# Out:
# req         WARNING
#
# DEFAULT CACHE ENABLED!
# 	Cache directory: C:\Users\srikr\AppData\Local\Temp\fastf1.
# 	Size: 24.0 KB
# RoundNumber                                                 7
# Country                                                 Spain
# Location                                            Barcelona
# OfficialEventName    FORMULA 1 AWS GRAN PREMIO DE ESPAÑA 2023
# EventDate                                 2023-06-04 00:00:00
# EventName                                  Spanish Grand Prix
# EventFormat                                      conventional
# Session1                                           Practice 1
# Session1Date                        2023-06-02 13:30:00+02:00
# Session1DateUtc                           2023-06-02 11:30:00
# Session2                                           Practice 2
# Session2Date                        2023-06-02 17:00:00+02:00
# Session2DateUtc                           2023-06-02 15:00:00
# ...

# %%
fastf1.get_session?
# Out:
# Signature:
# fastf1.get_session(
#     year: int,
#     gp: Union[str, int],
#     identifier: Union[int, str, NoneType] = None,
#     *,
#     backend: Optional[Literal['fastf1', 'f1timing', 'ergast']] = None,
#     force_ergast: bool = False,
# ) -> fastf1.core.Session
# Docstring:
# Create a :class:`~fastf1.core.Session` object based on year, event name
# and session identifier.
#
# .. note:: This function will return a :class:`~fastf1.core.Session`
#     object, but it will not load any session specific data like lap timing,
#     telemetry, ... yet. For this, you will need to call
#     :func:`~fastf1.core.Session.load` on the returned object.
#
# To get a testing session, use :func:`get_testing_session`.
#
# Examples:
#
#     Get the second free practice of the first race of 2021 by its session
#     name abbreviation::
#
#         >>> get_session(2021, 1, 'FP2')
#
#     Get the qualifying of the 2020 Austrian Grand Prix by full session
#     name::
#
# ...

# %%
data = fastf1.get_session(2023,'spanish','Race')
df = data.load()
# Out:
# logger      WARNING 	Failed to load schedule from FastF1 backend!
# req            INFO 	Using cached data for season_schedule
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.0.4]
# req            INFO 	Using cached data for driver_info
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Cannot load lap times for first lap from Ergast. Timing data is not available for this session.
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# ...

# %%
type(data)
# Out:
# NoneType

# %%
data

# %%
data
# Out:
# 2023 Season Round 7: Spanish Grand Prix - Race

# %%
data.load()
# Out:
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.0.4]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '44', '63', '11', '55', '18', '14', '31', '24', '10', '16', '22', '81', '21', '27', '23', '4', '20', '77', '2']

# %%
ver = data.get_driver('VER')

# %%
ver
# Out:
# DriverNumber                                                          1
# BroadcastName                                              M VERSTAPPEN
# Abbreviation                                                        VER
# DriverId                                                 max_verstappen
# TeamName                                                Red Bull Racing
# TeamColor                                                        3671C6
# TeamId                                                         red_bull
# FirstName                                                           Max
# LastName                                                     Verstappen
# FullName                                                 Max Verstappen
# HeadshotUrl           https://www.formula1.com/content/dam/fom-websi...
# CountryCode                                                         NED
# Position                                                            1.0
# ...

# %%
df_ver_fast = data.laps.pick_driver('VER').pick_fastest().get_car_data().add_distance()

# %%
df_ham_fast = data.laps.pick_driver('HAM').pick_fastest().get_car_data().add_distance()

# %%
df_ver_fast.head()
# Out:
#                      Date    RPM  Speed  nGear  Throttle  Brake  DRS Source  \
# 0 2023-06-04 14:23:28.524  11379    289      7       100  False    0    car
# 1 2023-06-04 14:23:28.724  11505    290      7       100  False    0    car
# 2 2023-06-04 14:23:29.004  11532    291      7       100  False    0    car
# 3 2023-06-04 14:23:29.325  10860    293      7       100  False    0    car
# 4 2023-06-04 14:23:29.605  10466    294      8       100  False    0    car
#
#                     Time            SessionTime    Distance
# 0 0 days 00:00:00.279000 0 days 02:22:28.517000   22.397500
# 1 0 days 00:00:00.479000 0 days 02:22:28.717000   38.508611
# 2 0 days 00:00:00.759000 0 days 02:22:28.997000   61.141944
# 3 0 days 00:00:01.080000 0 days 02:22:29.318000   87.267778
# 4 0 days 00:00:01.360000 0 days 02:22:29.598000  110.134444

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('dark_background')

# %%
df_ver_fast.set_index('Time',inplace=True)
df_ham_fast.set_index('Time',inplace=True)

# %%
fig, ax1 = plt.subplots(4,figsize=(25,20))

ax = ax1[0]
ax.plot(df_ver_fast['Speed'],color='blue',lw=1,label='VER')
ax.plot(df_ham_fast['Speed'],color='cyan',lw=1,label='HAM')

ax = ax1[1]
ax.plot(df_ver_fast['Throttle'],color='blue',lw=1)
ax.plot(df_ham_fast['Throttle'],color='cyan',lw=1)

ax = ax1[2]
ax.plot(df_ver_fast['DRS'],color='blue',lw=1)
ax.plot(df_ham_fast['DRS'],color='cyan',lw=1)

ax = ax1[3]
ax.plot(df_ver_fast['nGear'],color='blue',lw=1)
ax.plot(df_ham_fast['nGear'],color='cyan',lw=1)

fig.legend(loc=7)
fig.suptitle('VER v HAM',fontsize=30)
# Out:
# Text(0.5, 0.98, 'VER v HAM')

# %%
df_ham_fast.head()
# Out:
#                                           Date    RPM  Speed  nGear  Throttle  \
# Time
# 0 days 00:00:00.203000 2023-06-04 14:25:04.805  10901    295      8       100
# 0 days 00:00:00.443000 2023-06-04 14:25:05.045  10862    298      8       100
# 0 days 00:00:00.763000 2023-06-04 14:25:05.365  11104    301      8       100
# 0 days 00:00:00.963000 2023-06-04 14:25:05.565  11104    303      8       100
# 0 days 00:00:01.323000 2023-06-04 14:25:05.925  11261    306      8       100
#
#                         Brake  DRS Source            SessionTime
# Time
# 0 days 00:00:00.203000  False   12    car 0 days 02:24:04.798000
# 0 days 00:00:00.443000  False   12    car 0 days 02:24:05.038000
# 0 days 00:00:00.763000  False   12    car 0 days 02:24:05.358000
# 0 days 00:00:00.963000  False   12    car 0 days 02:24:05.558000
# 0 days 00:00:01.323000  False   12    car 0 days 02:24:05.918000

# %%
df_ham_fast.reset_index(inplace=True)
df_ver_fast.reset_index(inplace=True)
import datetime as dt

# %%
import pandas as pd
df_ham_fast['Time'].dtype
# Out:
# dtype('<m8[ns]')

# %%
df_ham_fast['Time'] = [round(n.total_seconds(),3) for n in df_ham_fast['Time']]

# %%
df_ver_fast['Time'] = [round(n.total_seconds(),3) for n in df_ver_fast['Time']]

# %%
df_ham_fast['Dist'] = df_ham_fast['Time']*df_ham_fast['Speed']
df_ver_fast['Dist'] = df_ver_fast['Time']*df_ver_fast['Speed']

# %%
df_ham_fast.head()
# Out:
#                          Date    RPM  Speed  nGear  Throttle  Brake  DRS  \
# Time
# 0.203 2023-06-04 14:25:04.805  10901    295      8       100  False   12
# 0.443 2023-06-04 14:25:05.045  10862    298      8       100  False   12
# 0.763 2023-06-04 14:25:05.365  11104    301      8       100  False   12
# 0.963 2023-06-04 14:25:05.565  11104    303      8       100  False   12
# 1.323 2023-06-04 14:25:05.925  11261    306      8       100  False   12
#
#       Source            SessionTime     Dist
# Time
# 0.203    car 0 days 02:24:04.798000   59.885
# 0.443    car 0 days 02:24:05.038000  132.014
# 0.763    car 0 days 02:24:05.358000  229.663
# 0.963    car 0 days 02:24:05.558000  291.789
# 1.323    car 0 days 02:24:05.918000  404.838

# %%
df_ver_fast.head()
# Out:
#                          Date    RPM  Speed  nGear  Throttle  Brake  DRS  \
# Time
# 0.279 2023-06-04 14:23:28.524  11379    289      7       100  False    0
# 0.479 2023-06-04 14:23:28.724  11505    290      7       100  False    0
# 0.759 2023-06-04 14:23:29.004  11532    291      7       100  False    0
# 1.080 2023-06-04 14:23:29.325  10860    293      7       100  False    0
# 1.360 2023-06-04 14:23:29.605  10466    294      8       100  False    0
#
#       Source            SessionTime     Dist
# Time
# 0.279    car 0 days 02:22:28.517000   80.631
# 0.479    car 0 days 02:22:28.717000  138.910
# 0.759    car 0 days 02:22:28.997000  220.869
# 1.080    car 0 days 02:22:29.318000  316.440
# 1.360    car 0 days 02:22:29.598000  399.840

# %%
df_ham_fast['Dist']-df_ver_fast['Dist']
# Out:
# Time
# 0.203    NaN
# 0.279    NaN
# 0.443    NaN
# 0.479    NaN
# 0.759    NaN
#           ..
# 75.920   NaN
# 76.003   NaN
# 76.280   NaN
# 76.323   NaN
# 76.563   NaN
# Name: Dist, Length: 579, dtype: float64

# %%
df_ver_fast['Dist'].dtype
# Out:
# dtype('float64')

# %%
def basic_plots(drivers,plots):
    import matplotlib.pyplot as plt
    plt.style.use('dark_background')
    fig, ax = plt.subplots(len(plots),figsize=(max(25,len(plots)*5),max(20,len(plots)*4)))
    data = fastf1.get_session(2023,'Monaco','Q')
    data.load()
    d_colors = {
        'VER': '#0600EF',
        'PER': '#0600EF',
        'HAM': '#00D2BE',
        'RUS': '#00D2BE',
        'LEC': '#DC0000',
        'SAI': '#DC0000',
        'OCO': '#0090FF',
        'GAS': '#0090FF',
        'HUL': '#FFFFFF',
        'MAG': '#FFFFFF',
        'STR': '#006F62',
        'ALO': '#006F62',
        'TSU': '#2B4562',
        'DEV': '#2B4562',
        'NOR': '#FF8700',
        'PIA': '#FF8700',
        'ZHO': '#900000',
        'BOT': '#900000',
        'SAR': '#005AFF',
        'ALB': '#005AFF'
    }
    d_linestyles = {
        'VER': '-',
        'PER': '--',
        'HAM': '--',
        'RUS': '-',
        'LEC': '-',
        'SAI': '--',
        'OCO': '-',
        'GAS': '--',
        'HUL': '-',
        'MAG': '--',
        'STR': '-',
        'ALO': '--',
        'TSU': '-',
        'DEV': '--',
        'NOR': '-',
        'PIA': '--',
        'ZHO': '--',
        'BOT': '-',
        'SAR': '--',
        'ALB': '-'
    }
    title = ''
    for d in drivers:
        title += f' {d} '
        df = data.laps.pick_driver(d).pick_fastest().get_car_data()
        df['Time'] = [round(n.total_seconds(),3) for n in df['Time']]
        df.set_index('Time',inplace=True)
        for i, p in enumerate(plots):
            ax[i].plot(df[p],color=d_colors[d],linestyle=d_linestyles[d])
            ax[i].set_ylabel(p)
    
    fig.legend(drivers,loc=5)
    fig.suptitle(title,fontsize=30)

# %%
basic_plots(['VER','ALO'],['Speed','Throttle','DRS','nGear'])
# Out:
# logger      WARNING 	Failed to load schedule from FastF1 backend!
# req            INFO 	Using cached data for season_schedule
# core           INFO 	Loading data for Monaco Grand Prix - Qualifying [v3.0.4]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# ...

# %%
session = fastf1.get_session(2020, 4, 'Q')
session.load()
fastest_lap = session.laps.pick_fastest()
tel = fastest_lap.telemetry
# Out:
# core           INFO 	Loading data for British Grand Prix - Qualifying [v3.0.4]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# ...

# %%
tel[tel['Source']=='car']
# Out:
#                        Date            SessionTime DriverAhead  \
# 4   2020-08-01 14:06:22.462 0 days 01:21:22.423000
# 6   2020-08-01 14:06:22.702 0 days 01:21:22.663000
# 8   2020-08-01 14:06:22.942 0 days 01:21:22.903000
# 11  2020-08-01 14:06:23.182 0 days 01:21:23.143000
# 13  2020-08-01 14:06:23.423 0 days 01:21:23.384000
# ..                      ...                    ...         ...
# 725 2020-08-01 14:07:45.423 0 days 01:22:45.384000
# 728 2020-08-01 14:07:45.663 0 days 01:22:45.624000
# 730 2020-08-01 14:07:45.903 0 days 01:22:45.864000
# 732 2020-08-01 14:07:46.143 0 days 01:22:46.104000
# 734 2020-08-01 14:07:46.383 0 days 01:22:46.344000
#
#      DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 4                      NaN 0 days 00:00:00.169000  11125    273      7
# 6                      NaN 0 days 00:00:00.409000  11311    276      7
# 8                      NaN 0 days 00:00:00.649000  11426    281      7
# ...

# %%
drivers = ['VER', 'HAM']
title = ''
for d in drivers:    
    title += f' {d} '

title
# Out:
# ' VER  HAM '

# %%
data.laps.pick_driver('HAM')
# Out:
# ---------------------------------------------------------------------------
# DataNotLoadedError                        Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 data.laps.pick_driver('HAM')
#
# File c:\Users\srikr\anaconda3\lib\site-packages\fastf1\core.py:1074, in Session.laps(self)
#    1068 @property
#    1069 def laps(self) -> "Laps":
#    1070     """:class:`Laps`: All laps from all drivers driven in this session.
#    1071
#    1072     Data is available after calling `Session.load` with ``laps=True``
#    1073     """
# -> 1074     return self._get_property_warn_not_loaded('_laps')
#
# File c:\Users\srikr\anaconda3\lib\site-packages\fastf1\core.py:1047, in Session._get_property_warn_not_loaded(self, name)
#    1045 def _get_property_warn_not_loaded(self, name):
#    1046     if not hasattr(self, name):
# -> 1047         raise DataNotLoadedError("The data you are trying to access has not "
# ...

# %%
# !pip install plotly

# %%
event = fastf1.get_event(2020, 'Bahrain')
# session.load()
# fastest_lap = session.laps.pick_fastest()
# tel = fastest_lap.telemetry

# %%
event.get_session_name(1)
# Out:
# 'Practice 1'

# %%
events = fastf1.get_event_schedule(2023)

# %%
events.get_event_by_round(1).EventName
# Out:
# 'Bahrain Grand Prix'

# %%
len(events)
# Out:
# 23

# %%
session = fastf1.get_session(2021, 'French Grand Prix', 'Q')
session.load()
session.results
# Out:
# logger      WARNING 	Failed to load schedule from FastF1 backend!
# req            INFO 	No cached data found for season_schedule. Loading data...
# _api           INFO 	Fetching season schedule...
# req            INFO 	Data has been written to cache!
# core           INFO 	Loading data for French Grand Prix - Qualifying [v3.0.4]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# ...

# %%
df = session.results
df.columns
# Out:
# Index(['DriverNumber', 'BroadcastName', 'Abbreviation', 'DriverId', 'TeamName',
#        'TeamColor', 'TeamId', 'FirstName', 'LastName', 'FullName',
#        'HeadshotUrl', 'CountryCode', 'Position', 'ClassifiedPosition',
#        'GridPosition', 'Q1', 'Q2', 'Q3', 'Time', 'Status', 'Points'],
#       dtype='object')

# %%
print(df['HeadshotUrl'].iloc[0])
# Out:
# https://www.formula1.com/content/dam/fom-website/drivers/M/MAXVER01_Max_Verstappen/maxver01.png.transform/1col/image.png

# %%
df.dtypes
# Out:
# DriverNumber                   object
# BroadcastName                  object
# Abbreviation                   object
# DriverId                       object
# TeamName                       object
# TeamColor                      object
# TeamId                         object
# FirstName                      object
# LastName                       object
# FullName                       object
# HeadshotUrl                    object
# CountryCode                    object
# Position                      float64
# ClassifiedPosition             object
# GridPosition                  float64
# Q1                    timedelta64[ns]
# Q2                    timedelta64[ns]
# Q3                    timedelta64[ns]
# Time                  timedelta64[ns]
# Status                         object
# Points                        float64
# dtype: object

# %%
events = fastf1._DRIVER_TEAM_MAPPING

# %%
len(events.keys())
# Out:
# 21

# %%
[events[x]['Abbreviation'] for x in events.keys()]
# Out:
# ['ALB',
#  'ALO',
#  'BOT',
#  'GAS',
#  'HAM',
#  'HUL',
#  'LAT',
#  'LEC',
#  'MAG',
#  'NOR',
#  'OCO',
#  'PER',
#  'RIC',
#  'RUS',
#  'SAI',
#  'MSC',
#  'STR',
#  'TSU',
#  'VER',
#  'VET',
#  'ZHO']

# %%
session = fastf1.get_session(2021, 'French Grand Prix', 'Q')
session.load()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 session = fastf1.get_session(2021, 'French Grand Prix', 'Q')
#       2 session.load()
#
# NameError: name 'fastf1' is not defined

# %%
session.results.Abbreviation.unique()
# Out:
# array(['VER', 'HAM', 'BOT', 'PER', 'SAI', 'GAS', 'LEC', 'NOR', 'ALO',
#        'RIC', 'OCO', 'VET', 'GIO', 'RUS', 'MSC', 'LAT', 'RAI', 'MAZ',
#        'STR', 'TSU'], dtype=object)

# %%
session.results.columns
# Out:
# Index(['DriverNumber', 'BroadcastName', 'Abbreviation', 'DriverId', 'TeamName',
#        'TeamColor', 'TeamId', 'FirstName', 'LastName', 'FullName',
#        'HeadshotUrl', 'CountryCode', 'Position', 'ClassifiedPosition',
#        'GridPosition', 'Q1', 'Q2', 'Q3', 'Time', 'Status', 'Points'],
#       dtype='object')

# %%
events = fastf1.get_event_schedule(2022)
events.get_event_by_round(0).EventName
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[220], line 2
#       1 events = fastf1.get_event_schedule(2022)
# ----> 2 events.get_event_by_round(0).EventName
#
# File c:\Users\srikr\anaconda3\lib\site-packages\fastf1\events.py:838, in EventSchedule.get_event_by_round(self, round)
#     830 """Get an :class:`Event` by its round number.
#     831
#     832 Args:
#    (...)
#     835     ValueError: The round does not exist in the event schedule
#     836 """
#     837 if round == 0:
# --> 838     raise ValueError("Cannot get testing event by round number!")
#     839 mask = self['RoundNumber'] == round
#     840 if not mask.any():
#
# ValueError: Cannot get testing event by round number!

# %%
events
# Out:
#     RoundNumber        Country           Location  \
# 0             0          Spain              Spain
# 1             0        Bahrain            Bahrain
# 2             1        Bahrain             Sakhir
# 3             2   Saudi Arabia             Jeddah
# 4             3      Australia          Melbourne
# 5             4          Italy              Imola
# 6             5  United States              Miami
# 7             6          Spain          Barcelona
# 8             7         Monaco             Monaco
# 9             8     Azerbaijan               Baku
# 10            9         Canada           Montréal
# 11           10  Great Britain        Silverstone
# 12           11        Austria          Spielberg
# 13           12         France       Le Castellet
# 14           13        Hungary           Budapest
# 15           14        Belgium  Spa-Francorchamps
# 16           15    Netherlands          Zandvoort
# 17           16          Italy              Monza
# ...

# %%
import numpy as np
x = np.array(tel['X'].values)
y = np.array(tel['Y'].values)

# %%
points = np.array([x, y]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)
gear = tel['nGear'].to_numpy().astype(float)
speed = tel['Speed'].to_numpy().astype(float)

# %%
segments
# Out:
# array([[[ -323, -1473],
#         [ -330, -1468]],
#
#        [[ -330, -1468],
#         [ -452, -1374]],
#
#        [[ -452, -1374],
#         [ -477, -1355]],
#
#        ...,
#
#        [[  -91, -1638],
#         [ -192, -1566]],
#
#        [[ -192, -1566],
#         [ -231, -1539]],
#
#        [[ -231, -1539],
#         [ -304, -1485]]], dtype=int64)

# %%
from matplotlib.collections import LineCollection
from matplotlib import cm
import matplotlib.pyplot as plt

# %%
cmap = cm.get_cmap('Paired')
lc_comp = LineCollection(segments, norm=plt.Normalize(1, cmap.N+1), cmap=cmap)
lc_comp.set_array(speed)
lc_comp.set_linewidth(4)
# Out:
# C:\Users\srikr\AppData\Local\Temp\ipykernel_21804\2623056993.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('Paired')

# %%
import matplotlib.colors
plt.gca().add_collection(lc_comp)
plt.axis('equal')
plt.tick_params(labelleft=False, left=False, labelbottom=False, bottom=False)

title = plt.suptitle(
    f"Fastest Lap Speed Visualization\n"
    f"{lap['Driver']} - {session.event['EventName']} {session.event.year}"
)

# cbar = plt.colorbar(mappable=lc_comp, label="Speed", boundaries=np.arange(50, 350, 25))
# cbar.set_ticks(np.arange(50, 350,25))
# cbar.set_ticklabels(np.arange(50,350,25))

norm= matplotlib.colors.Normalize(vmin=50, vmax=350)
sm = plt.cm.ScalarMappable(norm=norm, cmap = cmap)
plt.colorbar(lc_comp, ticks=np.arange(50,350,25))



plt.show()

# %%
speed
# Out:
# array([300., 301., 303., 304., 305., 305., 306., 307., 308., 308., 308.,
#        308., 308., 309., 309., 309., 309., 310., 310., 310., 309., 309.,
#        309., 310., 309., 309., 309., 309., 309., 309., 308., 308., 307.,
#        307., 307., 302., 298., 290., 282., 270., 259., 239., 219., 211.,
#        204., 198., 192., 185., 178., 175., 173., 171., 166., 162., 161.,
#        160., 160., 160., 163., 166., 168., 170., 174., 179., 181., 184.,
#        185., 186., 185., 185., 185., 185., 185., 186., 188., 191., 194.,
#        198., 203., 204., 206., 212., 218., 220., 222., 226., 230., 232.,
#        234., 236., 240., 244., 246., 249., 251., 253., 256., 260., 261.,
#        263., 265., 268., 269., 271., 271., 272., 273., 275., 275., 275.,
#        276., 277., 278., 278., 279., 280., 281., 282., 283., 283., 283.,
#        283., 283., 284., 286., 284., 283., 277., 272., 258., 244., 235.,
#        226., 218., 211., 204., 198., 192., 184., 176., 172., 168., 164.,
# ...

# %%
import fastf1
fastf1.__version__
# Out:
# '3.3.0'

# %%
session = fastf1.get_session(2024,'Bahrain','Q')
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (349.45 MB) C:\Users\srikr\AppData\Local\Temp\fastf1

# %%
session.load()
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Qualifying [v3.3.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/1/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "d:\Documents\code\python\F1-data-analysis\f1-data-analysis\Lib\site-packages\requests_cache\session.py", line 260, in _resend
#     response.raise_for_status()
#   File "d:\Documents\code\python\F1-data-analysis\f1-data-analysis\Lib\site-packages\requests\models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Backend fetch failed for url: https://ergast.com/api/f1/2024/1/qualifying.json
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# ...

# %%
session.get_circuit_info()
# Out:
# CircuitInfo(corners=              X            Y  Number Letter       Angle     Distance
# 0     42.405939  8329.202564       1        -246.615311   708.060978
# 1    820.781621  7879.043841       2        -101.177469   809.362397
# 2   1912.969997  8065.442167       3        -261.394562   921.305992
# 3   7487.745293  6790.710716       4        -349.599066  1499.507455
# 4   5820.228443  4860.740936       5        -211.501597  1772.563334
# 5   5180.404121  4214.598861       6         -76.374442  1865.747082
# 6   4276.202937  4156.240631       7        -258.953372  1961.823843
# 7   2490.099011  2458.600397       8        -114.654309  2220.817930
# 8   2711.155288  5950.242339       9        -344.907956  2593.741286
# 9   2100.132716  6613.999851      10        -270.022000  2682.887707
# 10  2120.985221  -663.995072      11        -100.999671  3457.963903
# 11  4981.251162  1603.747622      12        -272.812824  3861.817700
# ...

# %%
session.event
# Out:
# RoundNumber                                                   1
# Country                                                 Bahrain
# Location                                                 Sakhir
# OfficialEventName    FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2024
# EventDate                                   2024-03-02 00:00:00
# EventName                                    Bahrain Grand Prix
# EventFormat                                        conventional
# Session1                                             Practice 1
# Session1Date                          2024-02-29 14:30:00+03:00
# Session1DateUtc                             2024-02-29 11:30:00
# Session2                                             Practice 2
# Session2Date                          2024-02-29 18:00:00+03:00
# Session2DateUtc                             2024-02-29 15:00:00
# Session3                                             Practice 3
# Session3Date                          2024-03-01 15:30:00+03:00
# ...

# %%
lec = session.laps.pick_driver('LEC').pick_fastest().get_telemetry()
ver = session.laps.pick_driver('VER').pick_fastest().get_telemetry()
# lec = session.laps.pick_driver('LEC').get_telemetry()
#get_telemetry()

# %%
lec.head()
#.head()
# Out:
#                      Date            SessionTime DriverAhead  \
# 2 2024-03-01 16:38:38.850 0 days 00:52:03.177000
# 3 2024-03-01 16:38:38.875 0 days 00:52:03.202000
# 4 2024-03-01 16:38:38.925 0 days 00:52:03.252000
# 5 2024-03-01 16:38:39.075 0 days 00:52:03.402000
# 6 2024-03-01 16:38:39.085 0 days 00:52:03.412000
#
#    DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2                    NaN        0 days 00:00:00  11686    289      7
# 3                    NaN 0 days 00:00:00.025000  11700    290      7
# 4                    NaN 0 days 00:00:00.075000  11729    292      7
# 5                    NaN 0 days 00:00:00.225000  11239    292      7
# 6                    NaN 0 days 00:00:00.235000  10749    293      7
#
#    Throttle  Brake  DRS         Source   Distance  RelativeDistance   Status  \
# 2        99  False   12  interpolation   0.164005          0.000030  OnTrack
# 3        99  False   12            pos   2.193527          0.000407  OnTrack
# ...

# %%
ver.head()
# Out:
#                      Date            SessionTime DriverAhead  \
# 2 2024-03-01 16:59:09.798 0 days 01:12:34.125000
# 3 2024-03-01 16:59:09.837 0 days 01:12:34.164000
# 4 2024-03-01 16:59:09.889 0 days 01:12:34.216000
# 5 2024-03-01 16:59:10.016 0 days 01:12:34.343000
# 6 2024-03-01 16:59:10.049 0 days 01:12:34.376000          81
#
#    DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2              50.658889        0 days 00:00:00  11031    296      7
# 3              50.658889 0 days 00:00:00.039000  10912    297      7
# 4              50.658889 0 days 00:00:00.091000  10674    298      8
# 5              50.658889 0 days 00:00:00.218000  10715    299      8
# 6              50.658889 0 days 00:00:00.251000  10757    301      8
#
#    Throttle  Brake  DRS         Source   Distance  RelativeDistance   Status  \
# 2       100  False   12  interpolation   0.051314          0.000010  OnTrack
# ...

# %%
ver.iloc[-1]
# Out:
# Date                     2024-03-01 17:00:38.977000
# SessionTime                  0 days 01:14:03.304000
# DriverAhead                                      44
# DistanceToDriverAhead                    610.188056
# Time                         0 days 00:01:29.179000
# RPM                                           11581
# Speed                                           293
# nGear                                             7
# Throttle                                        100
# Brake                                         False
# DRS                                              12
# Source                                interpolation
# Distance                                5366.275233
# RelativeDistance                           0.997668
# Status                                      OnTrack
# X                                              -378
# Y                                              1322
# Z                                              -160
# Name: 703, dtype: object

# %%
import pandas as pd
dist_segments = np.arange(0,1.01,0.01)
dist_segments
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 import pandas as pd
# ----> 2 dist_segments = np.arange(0,1.01,0.01)
#       3 dist_segments
#
# NameError: name 'np' is not defined

# %%
dist_segments = session.get_circuit_info().marshal_sectors.Distance.to_list()
first = 0
last = dist_segments[0]
dist_segments[0] = 0 
dist_segments.append(last)
ver['dist_segments'] = pd.cut(ver.Distance,bins=dist_segments)
lec['dist_segments'] = pd.cut(lec.Distance,bins=dist_segments)
merged = pd.merge(ver.groupby('dist_segments')['Speed'].mean().reset_index(),lec.groupby('dist_segments')['Speed'].mean().reset_index(),on='dist_segments',suffixes=['_ver','_lec'],how='inner')
merged['Faster_Driver'] = merged['Speed_ver'] > merged['Speed_lec']
merged['Faster_Driver'] = merged['Faster_Driver'].map(lambda x: 'VER' if x else 'LEC')
merged
# Out:
#            dist_segments   Speed_ver   Speed_lec Faster_Driver
# 0         (0.0, 544.045]  314.857143  308.849057           VER
# 1     (544.045, 921.306]  159.986301  151.362319           VER
# 2    (921.306, 1317.606]  268.725000  269.868421           LEC
# 3    (1317.606, 1662.76]  191.862745  188.740741           VER
# 4    (1662.76, 1847.454]  236.956522  242.352941           LEC
# 5    (1847.454, 2008.66]  228.842105  228.909091           LEC
# 6    (2008.66, 2160.683]  240.333333  243.000000           LEC
# 7   (2160.683, 2378.413]  125.673913  121.875000           VER
# 8   (2378.413, 2573.526]  238.666667  240.173913           LEC
# 9   (2573.526, 2697.671]  135.655172  142.560000           LEC
# 10  (2697.671, 3338.897]  230.558442  230.189189           VER
# 11  (3338.897, 3590.962]  197.303030  197.351351           LEC
# 12  (3590.962, 3698.534]  243.750000  242.545455           VER
# 13  (3698.534, 3978.073]  264.500000  265.413793           LEC
# ...

# %%
ver.groupby('dist_segments')['Speed'].mean().reset_index()
# Out:
#            dist_segments       Speed
# 0         (0.0, 544.045]  314.857143
# 1     (544.045, 921.306]  159.986301
# 2    (921.306, 1317.606]  268.725000
# 3    (1317.606, 1662.76]  191.862745
# 4    (1662.76, 1847.454]  236.956522
# 5    (1847.454, 2008.66]  228.842105
# 6    (2008.66, 2160.683]  240.333333
# 7   (2160.683, 2378.413]  125.673913
# 8   (2378.413, 2573.526]  238.666667
# 9   (2573.526, 2697.671]  135.655172
# 10  (2697.671, 3338.897]  230.558442
# 11  (3338.897, 3590.962]  197.303030
# 12  (3590.962, 3698.534]  243.750000
# 13  (3698.534, 3978.073]  264.500000
# 14  (3978.073, 4241.476]  179.744186
# 15  (4241.476, 4764.263]  275.962963
# 16  (4764.263, 5036.015]  178.288889
# 17  (5036.015, 5355.889]  263.135135

# %%
ver
# Out:
#                        Date            SessionTime DriverAhead  \
# 2   2024-03-01 16:59:09.798 0 days 01:12:34.125000
# 3   2024-03-01 16:59:09.837 0 days 01:12:34.164000
# 4   2024-03-01 16:59:09.889 0 days 01:12:34.216000
# 5   2024-03-01 16:59:10.016 0 days 01:12:34.343000
# 6   2024-03-01 16:59:10.049 0 days 01:12:34.376000          81
# ..                      ...                    ...         ...
# 699 2024-03-01 17:00:38.416 0 days 01:14:02.743000          44
# 700 2024-03-01 17:00:38.755 0 days 01:14:03.082000          44
# 701 2024-03-01 17:00:38.770 0 days 01:14:03.097000          44
# 702 2024-03-01 17:00:38.836 0 days 01:14:03.163000          44
# 703 2024-03-01 17:00:38.977 0 days 01:14:03.304000          44
#
#      DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2                50.658889        0 days 00:00:00  11031    296      7
# 3                50.658889 0 days 00:00:00.039000  10912    297      7
# ...

# %%
pos session.get_circuit_info().marshal_sectors
# Out:
#               X            Y  Number Letter       Angle     Distance
# 0   -393.185167  1019.245720       1        -183.019352  5355.888934
# 1   -175.143181  6721.273251       2        -181.661190   544.045313
# 2   2029.269964  8072.488919       3         -92.263093   921.305992
# 3   5938.043810  7370.224849       4        -280.364943  1317.605635
# 4   6513.700757  5653.428140       5        -232.068722  1662.759874
# 5   5440.095703  4352.899291       6         -48.640796  1847.453785
# 6   3821.952450  3945.006672       7        -231.591606  2008.659942
# 7   2911.010730  2694.768477       8         -39.203254  2160.682675
# 8   2442.776275  3827.134558       9        -191.015371  2378.413309
# 9   2738.529117  5781.550811      10        -352.998227  2573.526139
# 10  1949.477533  6521.591324      11        -212.616743  2697.670520
# 11  1517.999905   158.359360      12        -179.828461  3338.896686
# 12  3148.505677  -112.147992      13         -34.684526  3590.962442
# ...

# %%
def rotate(xy, *, angle):
    rot_mat = np.array([[np.cos(angle), np.sin(angle)],
                        [-np.sin(angle), np.cos(angle)]])
    return np.matmul(xy, rot_mat)

track = pos.loc[:, ('X', 'Y')].to_numpy()

track_angle = circuit_info.rotation / 180 * np.pi

offset_vector = [500, 0]

# %%
session.get_circuit_info().rotation
# Out:
# 92.0

# %%
from matplotlib.collections import LineCollection
from matplotlib import colormaps as cm
import matplotlib.pyplot as plt

plt.style.use('dark_background')

import numpy as np
def rotate(xy, *, angle):
    rot_mat = np.array([[np.cos(angle), np.sin(angle)],
                        [-np.sin(angle), np.cos(angle)]])
    return np.matmul(xy, rot_mat)

def plot_segments(driver,ax=None):
    x = np.array(driver['X'].values)
    y = np.array(driver['Y'].values)
    points = np.array([x, y]).T.reshape(-1, 1, 2)
    points = rotate(points, angle=session.get_circuit_info().rotation * np.pi / 180)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    gear = driver['nGear'].to_numpy().astype(float)
    speed = driver['Speed'].to_numpy().astype(float)

    cmap = cm['magma']
    lc_comp = LineCollection(segments, norm=plt.Normalize(1, cmap.N+1), cmap=cmap)
    lc_comp.set_array(speed)
    lc_comp.set_linewidth(4)

    import matplotlib.colors
    if ax==None:
        fig, ax = plt.subplots()
    ax.add_collection(lc_comp)
    ax.axis('equal')
    ax.tick_params(labelleft=False, left=False, labelbottom=False, bottom=False)
    fig = ax.get_figure()
    # title = fig.suptitle(
    #     f"Fastest Lap Speed Visualization\n"
    #     f"{driver} - {session.event['EventName']} {session.event.year}"
    # )

    # cbar = plt.colorbar(mappable=lc_comp, label="Speed", boundaries=np.arange(50, 350, 25))
    # cbar.set_ticks(np.arange(50, 350,25))
    # cbar.set_ticklabels(np.arange(50,350,25))

    norm= matplotlib.colors.Normalize(vmin=50, vmax=450)
    sm = plt.cm.ScalarMappable(norm=norm, cmap = cmap)
    fig.colorbar(lc_comp, ticks=np.arange(50,450,50))


plot_segments(ver)
plot_segments(lec)

# %%
import fastf1.plotting
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
def rotate(xy, *, angle):
    rot_mat = np.array([[np.cos(angle), np.sin(angle)],
                        [-np.sin(angle), np.cos(angle)]])
    return np.matmul(xy, rot_mat)

def plot_speed_segments(session, drivers=[]):
    circuit_info = session.get_circuit_info()
    track_angle = circuit_info.rotation / 180 * np.pi
    lap = session.laps.pick_fastest()
    pos = lap.get_telemetry()
    dist_segments = circuit_info.marshal_sectors.Distance.to_list()
    first = 0
    last = dist_segments[0]
    dist_segments[0] = first
    dist_segments.append(last)
    pos['dist_segments'] = pd.cut(pos.Distance,bins=dist_segments)
    driver_df = pd.Series()
    for d in drivers:
        temp_df = session.laps.pick_driver(d).pick_fastest().get_telemetry()
        temp_df['dist_segments'] = pd.cut(temp_df.Distance,bins=dist_segments)
        temp_df = temp_df.groupby('dist_segments')['Speed'].mean().reset_index()
        temp_df['Driver'] = d
        driver_df = pd.concat([driver_df,temp_df])

    max_speeds = driver_df.groupby('dist_segments')['Speed'].max().reset_index()
    driver_df = pd.merge(driver_df,max_speeds,on=['dist_segments','Speed'],how='inner')
    driver_df = driver_df.sort_values('dist_segments')
    pos = pd.merge(driver_df,pos,on=['dist_segments'],how='right')
    track = pos.loc[:, ('X', 'Y')].to_numpy()
    rotated_track = rotate(track, angle=track_angle)
    pos['X'] = rotated_track[:, 0]
    pos['Y'] = rotated_track[:, 1]
    pos['Driver_Colors'] = pos['Driver'].map(lambda x: fastf1.plotting.driver_color(x) if isinstance(x,str) else None)
    fig = go.Figure()
    for d in driver_df.Driver.unique():
        dom_segments = driver_df[driver_df['Driver']==d]['dist_segments'].unique()
        sub_pos = pos[pos['dist_segments'].isin(dom_segments)]
        for ds in sub_pos.dist_segments.unique():
            plot_pos = sub_pos[sub_pos['dist_segments']==ds]
            fig.add_trace(
                go.Scatter(x=plot_pos['X'],y=plot_pos['Y'],mode='lines',line=dict(color=fastf1.plotting.driver_color(d)))
            )
            fig['data'][-1]['showlegend']=False
    fig.update_layout(dict(xaxis=dict(visible=False),
                           yaxis=dict(visible=False),
                           width=900,height=700,plot_bgcolor='rgba(0,0,0,0)',paper_bgcolor='rgba(0,0,0,0)'))
    
    for d in drivers:
        fig.add_trace(go.Scatter(
                    x=[None],
                    y=[None],
                    mode="lines",
                    name=d,
                    line=dict(color=fastf1.plotting.driver_color(d)),
                ))
        fig['data'][-1]['showlegend']=True
        fig['data'][-1]['name'] = d
    fig.show()
    # print(fig)


    
plot_speed_segments(session,['VER','LEC'])

# %%
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 fig
#
# NameError: name 'fig' is not defined

# %%
pos['Driver']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 pos['Driver']
#
# NameError: name 'pos' is not defined

# %%
fastf1.plotting.driver_color('NOR')
# Out:
# '#eeb370'

# %%
drivers=['VER','LEC']
circuit_info = session.get_circuit_info()
track_angle = circuit_info.rotation / 180 * np.pi
lap = session.laps.pick_fastest()
pos = lap.get_telemetry()
dist_segments = circuit_info.marshal_sectors.Distance.to_list()
first = 0
last = dist_segments[0]
dist_segments[0] = first
dist_segments.append(last)
pos['dist_segments'] = pd.cut(pos.Distance,bins=dist_segments)
driver_df = pd.Series()
for d in drivers:
    temp_df = session.laps.pick_driver(d).pick_fastest().get_telemetry()
    temp_df['dist_segments'] = pd.cut(temp_df.Distance,bins=dist_segments)
    temp_df = temp_df.groupby('dist_segments')['Speed'].mean().reset_index()
    temp_df['Driver'] = d
    driver_df = pd.concat([driver_df,temp_df])

max_speeds = driver_df.groupby('dist_segments')['Speed'].max().reset_index()
driver_df = pd.merge(driver_df,max_speeds,on=['dist_segments','Speed'],how='inner')
driver_df = driver_df.sort_values('dist_segments')
# driver_df
fig, ax = plt.subplots()
for d in driver_df.Driver.unique():
# d = 'VER'
    dom_segments = driver_df[driver_df['Driver']==d]['dist_segments'].unique()
    sub_pos = pos[pos['dist_segments'].isin(dom_segments)]
    # sub_pos = pd.merge(sub_pos,pos,on=['X','Y','dist_segments'],how='left')
    for ds in sub_pos.dist_segments.unique():
        track = sub_pos[sub_pos['dist_segments']==ds].loc[:, ('X', 'Y')].to_numpy()
        rotated_track = rotate(track, angle=track_angle)
        ax.plot(rotated_track[:, 0], rotated_track[:, 1], lw=4, color=fastf1.plotting.driver_color(d))
# sub_pos

# %%
session.laps.pick_driver('LEC').pick_box_laps().columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate'],
#       dtype='object')

# %%
fastf1.plotting.driver_color('LEC')
# Out:
# '#dc0000'

# %%
circuit_info = session.get_circuit_info()
lap = session.laps.pick_fastest()
lap.get_telemetry()
# Out:
#                        Date            SessionTime DriverAhead  \
# 2   2024-03-01 16:38:38.850 0 days 00:52:03.177000
# 3   2024-03-01 16:38:38.875 0 days 00:52:03.202000
# 4   2024-03-01 16:38:38.925 0 days 00:52:03.252000
# 5   2024-03-01 16:38:39.075 0 days 00:52:03.402000
# 6   2024-03-01 16:38:39.085 0 days 00:52:03.412000
# ..                      ...                    ...         ...
# 684 2024-03-01 16:40:07.416 0 days 00:53:31.743000
# 685 2024-03-01 16:40:07.566 0 days 00:53:31.893000
# 686 2024-03-01 16:40:07.716 0 days 00:53:32.043000
# 687 2024-03-01 16:40:07.886 0 days 00:53:32.213000
# 688 2024-03-01 16:40:08.015 0 days 00:53:32.342000
#
#      DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2                      NaN        0 days 00:00:00  11686    289      7
# 3                      NaN 0 days 00:00:00.025000  11700    290      7
# 4                      NaN 0 days 00:00:00.075000  11729    292      7
# ...

# %%
all_laps = session.laps.pick_quicklaps()

# %%
all_laps.head()
# Out:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 01:04:15.961000    VER            1 0 days 00:01:39.019000
# 1 0 days 01:05:53.935000    VER            1 0 days 00:01:37.974000
# 2 0 days 01:07:31.941000    VER            1 0 days 00:01:38.006000
# 3 0 days 01:09:09.917000    VER            1 0 days 00:01:37.976000
# 4 0 days 01:10:47.952000    VER            1 0 days 00:01:38.035000
#
#    LapNumber  Stint             PitOutTime PitInTime            Sector1Time  \
# 0        1.0    1.0 0 days 00:21:57.509000       NaT                    NaT
# 1        2.0    1.0                    NaT       NaT 0 days 00:00:31.342000
# 2        3.0    1.0                    NaT       NaT 0 days 00:00:31.388000
# 3        4.0    1.0                    NaT       NaT 0 days 00:00:31.271000
# 4        5.0    1.0                    NaT       NaT 0 days 00:00:31.244000
#
#              Sector2Time  ... FreshTyre             Team  \
# ...

# %%
all_laps.shape
# Out:
# (826, 31)

# %%
all_laps.Driver.unique()
# Out:
# array(['VER', 'GAS', 'PER', 'ALO', 'LEC', 'STR', 'SAR', 'MAG', 'DEV',
#        'TSU', 'ALB', 'ZHO', 'HUL', 'OCO', 'NOR', 'HAM', 'SAI', 'RUS',
#        'BOT'], dtype=object)

# %%
all_laps.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate'],
#       dtype='object')

# %%
alo = session.laps.pick_driver('ALO').pick_quicklaps()

# %%
alo.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate'],
#       dtype='object')

# %%
alo[~alo.PitInTime.isna()].LapNumber.to_list()
# Out:
# [14.0, 34.0]

# %%
session = fastf1.get_session(2023,'Monaco','R')
session.load()
# Out:
# logger      WARNING 	Failed to load schedule from FastF1 backend!
# req            INFO 	Using cached data for season_schedule
# core           INFO 	Loading data for Monaco Grand Prix - Race [v3.0.4]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# ...

# %%
lec = session.laps.pick_quicklaps().sort_values('LapTime')
lec[['LapTime','Driver','LapNumber']].head()
# Out:
#                     LapTime Driver  LapNumber
# 1159 0 days 00:01:15.650000    HAM       33.0
# 355  0 days 00:01:15.773000    LEC       46.0
# 126  0 days 00:01:15.831000    GAS       49.0
# 127  0 days 00:01:15.955000    GAS       50.0
# 359  0 days 00:01:15.956000    LEC       50.0

# %%
lec.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate'],
#       dtype='object')

# %%
session.laps.pick_driver('HAM').pick_quicklaps().sort_values('LapTime').iloc[0]['LapTime']
# Out:
# Timedelta('0 days 00:01:15.650000')
